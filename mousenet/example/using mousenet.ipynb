# %%
import os
import sys
sys.path.append('../cmouse')
import network
import mousenet_complete_pool
# Out:
# /home/iris/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/iris/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
net = network.load_network_from_pickle('./network_complete_updated_number(3,64,64).pkl')

# %%
net.draw_graph()

# %%
mousenet = mousenet_complete_pool.MouseNetCompletePool(net)

# %%
import torch
x = torch.rand(10,3,64,64)

# %%
mousenet.get_img_feature(x, ['VISp4'])
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.8022, 0.0000],
#         [0.0535, 0.1231, 0.0000,  ..., 1.9816, 0.0000, 0.0000],
#         [0.6117, 0.0000, 0.0000,  ..., 1.7611, 0.1192, 0.0000],
#         ...,
#         [0.9019, 0.0000, 0.0000,  ..., 0.7067, 2.6516, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.3202, 0.0000],
#         [0.5482, 0.2396, 0.3162,  ..., 1.7767, 0.1482, 0.0000]],
#        grad_fn=<AsStridedBackward>)

# %%
OUTPUT_AREAS = ['VISp5', 'VISl5', 'VISrl5', 'VISli5', 'VISpl5', 'VISal5', 'VISpor5']

mousenet.get_img_feature(x, OUTPUT_AREAS)
# Out:
# tensor([[0.4565, 0.4604, 0.4855,  ..., 0.3423, 0.3167, 0.4233],
#         [0.3582, 0.4085, 0.5618,  ..., 0.3743, 0.3896, 0.3594],
#         [0.4355, 0.3785, 0.3490,  ..., 0.3713, 0.3831, 0.3976],
#         ...,
#         [0.4425, 0.3198, 0.2973,  ..., 0.3428, 0.3471, 0.3999],
#         [0.4388, 0.3005, 0.3328,  ..., 0.3648, 0.3901, 0.3742],
#         [0.5032, 0.3846, 0.4011,  ..., 0.3401, 0.3410, 0.3609]],
#        grad_fn=<CatBackward>)
