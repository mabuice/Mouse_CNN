# %%
import sys
sys.path.append('../')
sys.path.append('../cmouse/')
sys.path.append('../mouse_cnn/')
from anatomy import *
from architecture import *
# %matplotlib inline

import os
DATA_DIR = os.environ['DATA_DIR']
from config import *
# Out:
# /home/iris/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/iris/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
architecture = Architecture()
anet = gen_anatomy(architecture)

# %%
anet.draw_graph()

# %%
from config import *
from network import Network
network = Network()
network.construct_from_anatomy(anet, architecture)
# Out:
# constructing layer 0: LGNd to VISp4
# constructing layer 1: VISp4 to VISp2/3
# constructing layer 2: VISp4 to VISl4
# kernel width: 0.3131697503589799 mm, 9.730945855284313 pixels
# VISp4->VISl4: dw=9.730945855284313, dp=0.029706808229549114
# kernel width: 0.3131697503589799 mm, 9.730945855284313 pixels
# constructing layer 3: VISp4 to VISrl4
# kernel width: 0.30668812410728813 mm, 9.529545962615547 pixels
# VISp4->VISrl4: dw=9.529545962615547, dp=0.03198106714359259
# kernel width: 0.30668812410728813 mm, 9.529545962615547 pixels
# constructing layer 4: VISp4 to VISli4
# kernel width: 0.29668027526842367 mm, 9.21857775745771 pixels
# VISp4->VISli4: dw=9.21857775745771, dp=0.031883586609849614
# kernel width: 0.29668027526842367 mm, 9.21857775745771 pixels
# constructing layer 5: VISp4 to VISpl4
# kernel width: 0.2906250141209135 mm, 9.030426065608529 pixels
# VISp4->VISpl4: dw=9.030426065608529, dp=0.03213559858582107
# kernel width: 0.2906250141209135 mm, 9.030426065608529 pixels
# constructing layer 6: VISp4 to VISal4
# kernel width: 0.27711158541754605 mm, 8.610530967563523 pixels
# VISp4->VISal4: dw=8.610530967563523, dp=0.038994987958822905
# kernel width: 0.27711158541754605 mm, 8.610530967563523 pixels
# constructing layer 7: VISp4 to VISpor4
# kernel width: 0.2768268646852876 mm, 8.601684001896157 pixels
# VISp4->VISpor4: dw=8.601684001896157, dp=0.013296069337288361
# kernel width: 0.2768268646852876 mm, 8.601684001896157 pixels
# constructing layer 8: VISp2/3 to VISp5
# constructing layer 9: VISp2/3 to VISl4
# kernel width: 0.32579418585587894 mm, 9.610451108079502 pixels
# VISp2/3->VISl4: dw=9.610451108079502, dp=0.03837648783050875
# kernel width: 0.32579418585587894 mm, 9.610451108079502 pixels
# constructing layer 10: VISp2/3 to VISrl4
# kernel width: 0.3393963174900399 mm, 10.011694060566054 pixels
# VISp2/3->VISrl4: dw=10.011694060566054, dp=0.031912903105178886
# kernel width: 0.3393963174900399 mm, 10.011694060566054 pixels
# constructing layer 11: VISp2/3 to VISli4
# kernel width: 0.303292435799537 mm, 8.946682452433935 pixels
# VISp2/3->VISli4: dw=8.946682452433935, dp=0.04520005955896701
# kernel width: 0.303292435799537 mm, 8.946682452433935 pixels
# constructing layer 12: VISp2/3 to VISpl4
# kernel width: 0.28423396743710383 mm, 8.384485561440094 pixels
# VISp2/3->VISpl4: dw=8.384485561440094, dp=0.04736957880247022
# kernel width: 0.28423396743710383 mm, 8.384485561440094 pixels
# constructing layer 13: VISp2/3 to VISal4
# kernel width: 0.2661111048399571 mm, 7.849887669612251 pixels
# VISp2/3->VISal4: dw=7.849887669612251, dp=0.06254368533349568
# kernel width: 0.2661111048399571 mm, 7.849887669612251 pixels
# constructing layer 14: VISp2/3 to VISpor4
# kernel width: 0.3074160287709884 mm, 9.068322402937177 pixels
# VISp2/3->VISpor4: dw=9.068322402937177, dp=0.012717719522095437
# kernel width: 0.3074160287709884 mm, 9.068322402937177 pixels
# constructing layer 15: VISl4 to VISl2/3
# constructing layer 16: VISl4 to VISpor4
# kernel width: 0.20467806500419627 mm, 7.016772352693592 pixels
# VISl4->VISpor4: dw=7.016772352693592, dp=0.013607370064435931
# kernel width: 0.20467806500419627 mm, 7.016772352693592 pixels
# constructing layer 17: VISrl4 to VISrl2/3
# constructing layer 18: VISrl4 to VISpor4
# kernel width: 0.09722331272965823 mm, 3.960124571322564 pixels
# VISrl4->VISpor4: dw=3.960124571322564, dp=0.07434869862634193
# kernel width: 0.09722331272965823 mm, 3.960124571322564 pixels
# constructing layer 19: VISli4 to VISli2/3
# constructing layer 20: VISli4 to VISpor4
# kernel width: 0.1551310211234763 mm, 8.978710176428532 pixels
# VISli4->VISpor4: dw=8.978710176428532, dp=0.01743572807653758
# kernel width: 0.1551310211234763 mm, 8.978710176428532 pixels
# constructing layer 21: VISpl4 to VISpl2/3
# constructing layer 22: VISpl4 to VISpor4
# kernel width: 0.02218580298946117 mm, 1.4967174562406373 pixels
# VISpl4->VISpor4: dw=1.4967174562406373, dp=0.18969391574040495
# kernel width: 0.02218580298946117 mm, 1.4967174562406373 pixels
# constructing layer 23: VISal4 to VISal2/3
# constructing layer 24: VISal4 to VISpor4
# kernel width: 0.03798395306171127 mm, 1.780286626437314 pixels
# VISal4->VISpor4: dw=1.780286626437314, dp=0.551099301396264
# kernel width: 0.03798395306171127 mm, 1.780286626437314 pixels
# constructing layer 25: VISpor4 to VISpor2/3
# constructing layer 26: VISp5 to VISl4
# kernel width: 0.3115343001682312 mm, 9.796969949282792 pixels
# VISp5->VISl4: dw=9.796969949282792, dp=0.042248546533989385
# kernel width: 0.3115343001682312 mm, 9.796969949282792 pixels
# constructing layer 27: VISp5 to VISrl4
# kernel width: 0.31140702164466866 mm, 9.792967359937547 pixels
# VISp5->VISrl4: dw=9.792967359937547, dp=0.04170449230853929
# kernel width: 0.31140702164466866 mm, 9.792967359937547 pixels
# constructing layer 28: VISp5 to VISli4
# kernel width: 0.31431193825085707 mm, 9.884319678705118 pixels
# VISp5->VISli4: dw=9.884319678705118, dp=0.04288200205446676
# kernel width: 0.31431193825085707 mm, 9.884319678705118 pixels
# constructing layer 29: VISp5 to VISpl4
# kernel width: 0.2782514078998896 mm, 8.750306724071065 pixels
# VISp5->VISpl4: dw=8.750306724071065, dp=0.053400161422079165
# kernel width: 0.2782514078998896 mm, 8.750306724071065 pixels
# constructing layer 30: VISp5 to VISal4
# kernel width: 0.23903644254899498 mm, 7.517094724951174 pixels
# VISp5->VISal4: dw=7.517094724951174, dp=0.06423554378937324
# kernel width: 0.23903644254899498 mm, 7.517094724951174 pixels
# constructing layer 31: VISp5 to VISpor4
# kernel width: 0.2982721292927696 mm, 9.379908041624509 pixels
# VISp5->VISpor4: dw=9.379908041624509, dp=0.0158739643279607
# kernel width: 0.2982721292927696 mm, 9.379908041624509 pixels
# constructing layer 32: VISl2/3 to VISl5
# constructing layer 33: VISl2/3 to VISpor4
# kernel width: 0.2105672858643026 mm, 7.123146134777606 pixels
# VISl2/3->VISpor4: dw=7.123146134777606, dp=0.016114239045357723
# kernel width: 0.2105672858643026 mm, 7.123146134777606 pixels
# constructing layer 34: VISrl2/3 to VISrl5
# constructing layer 35: VISrl2/3 to VISpor4
# kernel width: 0.1054124017991113 mm, 4.043649357027149 pixels
# VISrl2/3->VISpor4: dw=4.043649357027149, dp=0.06351736941941721
# kernel width: 0.1054124017991113 mm, 4.043649357027149 pixels
# constructing layer 36: VISli2/3 to VISli5
# constructing layer 37: VISli2/3 to VISpor4
# kernel width: 0.16928823409601915 mm, 8.371405491255276 pixels
# VISli2/3->VISpor4: dw=8.371405491255276, dp=0.02186303092177284
# kernel width: 0.16928823409601915 mm, 8.371405491255276 pixels
# constructing layer 38: VISpl2/3 to VISpl5
# constructing layer 39: VISpl2/3 to VISpor4
# kernel width: 0.059520810522482794 mm, 2.3683706098217634 pixels
# VISpl2/3->VISpor4: dw=2.3683706098217634, dp=0.0535442721630687
# kernel width: 0.059520810522482794 mm, 2.3683706098217634 pixels
# constructing layer 40: VISal2/3 to VISal5
# constructing layer 41: VISal2/3 to VISpor4
# kernel width: 0.013816774913534231 mm, 0.6051654386085802 pixels
# VISal2/3->VISpor4: dw=0.6051654386085802, dp=4.361723814045718
# kernel width: 0.013816774913534231 mm, 0.6051654386085802 pixels
# constructing layer 42: VISpor2/3 to VISpor5
# constructing layer 43: VISl5 to VISpor4
# kernel width: 0.21543657468165092 mm, 7.474571650604388 pixels
# VISl5->VISpor4: dw=7.474571650604388, dp=0.01890355943693985
# kernel width: 0.21543657468165092 mm, 7.474571650604388 pixels
# constructing layer 44: VISrl5 to VISpor4
# kernel width: 0.11036336508761051 mm, 4.384797381295216 pixels
# VISrl5->VISpor4: dw=4.384797381295216, dp=0.06406152427868221
# kernel width: 0.11036336508761051 mm, 4.384797381295216 pixels
# constructing layer 45: VISli5 to VISpor4
# kernel width: 0.14836543247338876 mm, 7.584947771438168 pixels
# VISli5->VISpor4: dw=7.584947771438168, dp=0.028161071736155296
# kernel width: 0.14836543247338876 mm, 7.584947771438168 pixels
# constructing layer 46: VISpl5 to VISpor4
# kernel width: 0.05439202462020661 mm, 2.144605758108941 pixels
# VISpl5->VISpor4: dw=2.144605758108941, dp=0.07862935706833563
# kernel width: 0.05439202462020661 mm, 2.144605758108941 pixels
# constructing layer 47: VISal5 to VISpor4
# kernel width: 0.01487094019389027 mm, 0.6874835478668775 pixels
# VISal5->VISpor4: dw=0.6874835478668775, dp=4.213042700919179
# kernel width: 0.01487094019389027 mm, 0.6874835478668775 pixels

# %%
network.draw_graph()

# %%
from network import save_network_to_pickle
save_network_to_pickle(network, 'network_complete_updated_number(3,64,64).pkl')

# %%
from network import load_network_from_pickle
network = load_network_from_pickle('network_complete_updated_number(3,64,64).pkl')
