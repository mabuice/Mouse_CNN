# %%
import os
import sys
sys.path.append('../cmouse')
import network

# %%
net = network.load_network_from_pickle('./network_(3,64,64).pkl')

# %%
net.draw_graph()
# Out:
# /home/iris/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/iris/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
mousenet = network.MouseNet(net)

# %%
import torch
x = torch.rand(10,3,64,64)

# %%
mousenet.get_img_feature(x, ['VISp4'])
# Out:
# tensor([[0.0000, 0.0000, 0.3733,  ..., 2.5780, 2.5439, 2.2546],
#         [0.0000, 0.0000, 0.0000,  ..., 0.9476, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 1.4694, 2.5041, 1.1432],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 2.7778, 2.1280, 0.2492],
#         [0.0000, 0.5162, 0.1848,  ..., 1.3568, 1.5827, 1.0810],
#         [0.0000, 0.0000, 0.0000,  ..., 1.5107, 1.7767, 0.3740]],
#        grad_fn=<AsStridedBackward>)

# %%
OUTPUT_AREAS = ['VISp5', 'VISl5', 'VISrl5', 'VISli5', 'VISpl5', 'VISal5', 'VISpor5']

mousenet.get_img_feature(x, OUTPUT_AREAS)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ..., -0.0400,  0.0498, -0.1484],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0222, -0.1946,  0.2359],
#         [ 0.1586,  0.0000,  0.0000,  ...,  0.1803,  0.0454, -0.2158],
#         ...,
#         [ 0.0000,  0.0000,  0.1161,  ..., -0.1520, -0.5242, -0.3193],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.1479, -0.3224, -0.3724],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.1482, -0.1449,  0.2283]],
#        grad_fn=<CatBackward>)
