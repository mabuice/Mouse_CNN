# %%
import os
import sys
sys.path.append('../cmouse')
import network
import mousenet_complete

# %%
net = network.load_network_from_pickle('./network_complete_(3,64,64).pkl')

# %%
net.draw_graph()

# %%
mousenet = mousenet_complete.MouseNet(net)

# %%
import torch
x = torch.rand(10,3,64,64)

# %%
mousenet.get_img_feature(x, ['VISp4'])
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0798, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.5974, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        grad_fn=<AsStridedBackward>)

# %%
OUTPUT_AREAS = ['VISp5', 'VISl5', 'VISrl5', 'VISli5', 'VISpl5', 'VISal5', 'VISpor5']

mousenet.get_img_feature(x, OUTPUT_AREAS)
# Out:
# tensor([[ 0.7199,  0.0000,  0.0000,  ..., -0.0317,  0.2590,  0.0485],
#         [ 0.8717,  0.0000,  0.0000,  ..., -0.0369,  0.2642,  0.1864],
#         [ 0.0000,  0.0000,  0.2171,  ...,  0.0514,  0.4655,  0.0759],
#         ...,
#         [ 0.9144,  0.0000,  0.0000,  ...,  0.4066, -0.0348, -0.1180],
#         [ 0.4751,  0.0000,  0.0000,  ...,  0.2914, -0.0476, -0.2981],
#         [ 0.2448,  0.0000,  0.4152,  ...,  0.0496,  0.3359, -0.1195]],
#        grad_fn=<CatBackward>)
