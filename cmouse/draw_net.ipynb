# %%
import sys
sys.path.append('../')
sys.path.append('./tests')
import network, mousenet
from network import *
from mousenet import *
# %matplotlib inline

# %%
from test_network import *
net = test_network()
net.draw_graph()

# %%
from test_gen_anatomy import *
anet = test_gen_anatomy()
anet.draw_graph()
