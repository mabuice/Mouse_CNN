# %%
import sys
sys.path.append('../')
sys.path.append('../../')
sys.path.append('../tests')
import network, mousenet
from network import *
from mousenet import *
# %matplotlib inline

# %%
from test_network import *
net = test_network()
net.draw_graph()

# %%
from gen_anatomy import *
anet = gen_anatomy(data_folder='../data_files')
anet.draw_graph()
