# %%
import sys
sys.path.append('../')
sys.path.append('../../')
from anatomy import *
from network import *

# %%
anet = gen_anatomy()
net = Network()
net.construct_from_anatomy(anet)

# %%
net.draw_graph()
